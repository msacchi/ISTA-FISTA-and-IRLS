# %%
# ISTA, FISTA and IRLS example

using LinearAlgebra, PyPlot, Printf, SparseArrays, FFTW, SeisProcessing, SeisMain,SeisReconstruction

# %%
include("fista.jl")
include("ista.jl")
include("power_iteration.jl")
include("irls.jl")
# Out:
# IRLS (generic function with 1 method)

# %% [markdown]
# Below is the main script where I test ISTA, FISTA and IRLS for a simple CS problem. A random matrix of size N x M compresses a sparse signal $x$ via $A x = y$. The random matrix is of size $N \times M$ with $N<M$. Then we try to recover $x$ via sparse solvers. In other words, we estimate $x$ by minimizing the $l_2-l_1$ cost function $J$ given by
#
# $$ J = \| A x - y\|_2^2 + \lambda \|x\|_1$$
#
# The cost function above is minimized via ISTA, FISTA and IRLS.In the examples below, we use the same
# value of $\lambda$ and the same maximum iteration number for the three tested methods.

# %%
 N = 40
 M = 150
 A = randn(N,M)
 
 
 xt = (Array(sprandn(M,1,0.12)))            # True
  y = A*xt                                 # Compressed signal y (observations)
  e = 0.0001*maximum(y)*randn(size(y))      # Add noise to observations 
  y = y + e

  λ = 1.0

  NITER = 1000
  
  x1,J1 = ISTA(A,y,NITER, λ)
  x2,J2 = FISTA(A,y,NITER, λ)
  x3,J3 = IRLS(A,y,NITER, λ)

figure(1,figsize=(7,6))

subplot(421); plot(xt); title("True sparse signal x")
subplot(422); plot(y);  title("Data y = A x + e")
subplot(423); plot(x1);  title("Recovered x via ISTA")
subplot(425); plot(x1);  title("Recovered x via FISTA")
subplot(427); plot(x1);  title("Recovered x via IRLS")


tight_layout()
savefig("fig_1_comparison.pdf")
savefig("fig_1_comparison.PNG")
rmse(a,b) = sum((a-b).^2)/sum(b.^2)

@printf "rmse for ISTA    %0.12e  \n" rmse(x1,xt);
@printf "rmse for FISTA   %0.12e  \n" rmse(x2,xt);
@printf "rmse for IRLS    %0.12e  \n" rmse(x3,xt);
# Out:
# rmse for ISTA    4.517650984143e-01
# rmse for FISTA   4.080987937290e-01
# rmse for IRLS    4.011404968666e-01
# Figure(PyObject <Figure size 700x600 with 5 Axes>)

# %%
figure(2,figsize=(7,6))
k=collect(1:1:length(J1))
        semilogy(k,J1,"--",k,J2,"-.",k,J3)
axis([-10,400,9,300])
legend(["ISTA", "FISTA", "IRLS"])
minimum(J1)
xlabel("Iteration")
ylabel(L"Cost function $J$")
savefig("convergence.pdf")
savefig("convergence.PNG")
# Out:
# Figure(PyObject <Figure size 700x600 with 1 Axes>)

# %%
(23-23*42/100)*30
# Out:
# 400.2

# %%
30*23*8.5/100
# Out:
# 58.65
